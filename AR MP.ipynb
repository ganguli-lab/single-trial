# %%
using Gadfly

include("armp.jl")
using ARMP

# %% [markdown]
# ### Samples from an N-dimensional autoregressive process for T time steps

# %%
function sampleAR(N, T, phi)
    p = sqrt(1 - phi^2) * eye(N);
    X = zeros(N, T)
    X[:, 1] = p * randn(N);
    for t in 2:T
        X[:, t] = phi * X[:, t - 1] + randn(N);
    end
    return X;
end
# Out:
# sampleAR (generic function with 1 method)

# %% [markdown]
# ### Normalize sample covariance's eigenvalues

# %%
function sampleSV2(N, T, alpha, nTrial)
    D = Float64[];
    for kTrial in 1:nTrial
        X = sampleAR(N, T, alpha);
        d, _ = eig(X * X' / T);
        D = [D, d];
    end
    return D;
end
# Out:
# sampleSV2 (generic function with 1 method)

# %% [markdown]
# ### Solve for the lower and upper eigenvalue bounds of the correlated noise

# %%
model = ARMPModel(0.2, 0.2)
l, u = lb(model), ub(model)
println(l);
println(u);
# Out:
# 0.30682543634511816
# 2.260584135595237

# %%
spec = spectrum(model)
x = linspace(l + 1e-6, u - 1e-6, 20)
plot(x=x, y=map(spec, x), Geom.point)
# Out:
# Plot(...)

# %% [markdown]
# ### Numerical verification

# %%
phi = 0.1;
cs = linspace(0.01, 0.99, 101);
cData, dData = Float64[], Float64[];
for c in cs[1:10:end]
    N = 200; T = int(N / c);
    cData = [cData, c * ones(N)];
    dData = [dData, sampleSV2(N, T, phi, 1)];
end
plot(
layer(x=cs, y=map(c -> lb(c, phi), cs), Theme(default_color=color("blue")), Geom.line),
layer(x=cs, y=map(c -> ub(c, phi), cs), Theme(default_color=color("red")), Geom.line),
layer(x=cData, y=dData, Theme(default_point_size=0.5mm, highlight_width=0mm), Geom.point),
Guide.XLabel("N / T"), Guide.YLabel("Eigval"), Scale.y_continuous)
# Out:
# Plot(...)

# %%
a, b = 1, 2
# Out:
# (1,2)

# %%
1im
# Out:
# 0 + 1im
